# %% [markdown]
# 1.shift+enter=next cell
# ~whenever using a system command just initiate it with "!"

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi its
# bogomips	: 4399.99
# ...

# %% [markdown]
# 2.the above command is a unix command which is used by google collab to check the cpu information allocated to us
# Note:-while writing pyhton function we shouldnot use this exclaimatory mark

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13286772 kB
# MemFree:         9518340 kB
# MemAvailable:   12268784 kB
# Buffers:          124856 kB
# Cached:          2826212 kB
# SwapCached:            0 kB
# Active:           438800 kB
# Inactive:        3120604 kB
# Active(anon):       1812 kB
# Inactive(anon):   608912 kB
# Active(file):     436988 kB
# Inactive(file):  2511692 kB
# Unevictable:           8 kB
# Mlocked:               8 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               316 kB
# Writeback:             0 kB
# AnonPages:        608380 kB
# Mapped:           408924 kB
# Shmem:              2380 kB
# KReclaimable:      85632 kB
# Slab:             122104 kB
# SReclaimable:      85632 kB
# SUnreclaim:        36472 kB
# KernelStack:        5088 kB
# PageTables:         9004 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6643384 kB
# Committed_AS:    2641284 kB
# ...

# %% [markdown]
# 3.The above code is to check the memory info and by being the code cell if you press "enter+shift" you'll get it executed

# %% [markdown]
# 4.to upload files click on last icon in left hand side->choose upload files to upload from pc/right click and choose upload
#
# ~like when needed to upload some for datasets and all while making ml models

# %% [markdown]
# 5.when clicked on mount drive ->will connect the drive to google collab to let it access all the files in drive
#
# ~i.e while uploading large datasets of like 1-2GB becomes slow/tough directly on GC ,we upload it to our drive and then access it from there

# %% [markdown]
# 6.Almost all python and ml libraries are pre-installed in it ,but if we still need some we can do it
#
# ~simple go to chrome search library name followed by pypi
# "pandas pypi" copy it from there
#
# ~come and paste it with exclaimatory mark at start,run it and all set

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# 7.the above line of code to import the installed library with the name updated along for further use

# %% [markdown]
# 8.Now if we want to add/load any dataset that has been uploaded to the google collab to the pandas dataframe to work on it
#
# ~go to the lat option in lefthandside
# ~click on the 3 dots in front of the file from the folder you want to add
# ~click on copy path and then run the command given below

# %%
df=pd.read_csv("/content/sample_data/california_housing_test.csv")

# %% [markdown]
# 9.~df =name given to the data frame
#
# ~pd=pandas renamed
#
# ~read.csv=to read the content of the files whose path has been provided

# %% [markdown]
# 10.To print the content of it now we'll use head function from this "CSV" i.e comman separated values file
#
# ~this .head() func will print the first file of our dataset

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# 11.To print all the files that are present in the environment

# %%
# !ls
# Out:
# sample_data

# %%
print("MACHINE HI TO LEARNING HHHH !!!")
# Out:
# MACHINE HI TO LEARNING HHHH !!!

# %% [markdown]
# 12.we can run simple python commands
