# %% [markdown]
# Important sites where we can get data from
#
# 1.KAGGLE:- also organizes competitions for data scientists and ml
#
# 2.UCI Machine Learning Repository :-collect the data we want
#
# 3.Google dataset Search:-exclusively to get datasets

# %%
#to uploat the downloaded data set here
import pandas as pd
#loading a dataset to a pandas dataframe
dataset=pd.read_csv('path of the file ')
dataset.head()
